# %%
print ("This was printed from Visual Studio")
# Out:
# This was printed from Visual Studio

# %% [markdown]
# ajldjdjdlll
# ajddjjldl

# %%
print ("This one is printed from anaconda juypter notebook")
# Out:
# This one is printed from anaconda juypter notebook
